# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
import csv

# %%
# walk2d_df = pd.DataFrame(pd.read_csv("../data_files/randomwalk2d.csv", index_col=0, header=None))
df = pd.DataFrame(pd.read_csv("../data_files/spherediffusion2.csv"))
print(df)
# Out:
#                x           y   t
# 0        0.00000    0.000000  298
# 1       -4.70099   -0.058700  298
# 2      -10.78310    0.556052  298
# 3      -12.94810    5.332160  298
# 4      -10.33450    7.551440  298
# ...          ...         ...  ...
# 9996  -231.13700 -604.528000  298
# 9997  -231.03100 -606.566000  298
# 9998  -234.03700 -604.465000  298
# 9999  -236.63500 -608.471000  298
# 10000 -232.47600 -610.776000  298
#
# [10001 rows x 3 columns]

# %%
fig, ax = plt.subplots()

x = df["x"]
y =  df["y"]

t = "path"
# plt.plot(x,y, marker='o', ms=1, linestyle='None')
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
ax.set_title(t)
ax.set_aspect('equal', adjustable='box')
plt.tight_layout()

# %%
# t = "path"
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# model1 = np.poly1d(np.polyfit(df.x, df.y, 1))

# polyline = np.linspace(x[1], x[[len(x)-1]], len(x))
# print(len(x))
# print(x[len(x)-1])

# plt.scatter(df.x, df.y)

# plt.plot(polyline, model1(polyline), color='green')

# def adjR(x, y, degree):
#     results = {}
#     coeffs = np.polyfit(x, y, degree)
#     p = np.poly1d(coeffs)
#     yhat = p(x)
#     ybar = np.sum(y)/len(y)
#     ssreg = np.sum((yhat-ybar)**2)
#     sstot = np.sum((y - ybar)**2)
#     results['r_squared'] = 1- (((1-(ssreg/sstot))*(len(y)-1))/(len(y)-degree-1))

#     return results

# #calculated adjusted R-squared of each model
# print(adjR(df.x, df.y, 1))
