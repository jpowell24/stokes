# 2996  ...  3.416880e-16  3.381390e-16   3.681100e-16  3.714720e-16
# 2997  ...  8.810930e-16  8.629810e-16   8.580390e-16  9.227240e-16
# 2998  ...  3.015310e-16  2.968360e-16   2.843250e-16  2.525060e-16
#
#        7.29921e-16   7.20959e-16   6.58186e-16   6.92182e-16   6.86085e-16  \
# 0     1.277510e-15  1.289760e-15  1.286280e-15  1.324380e-15  1.315710e-15
# 1     2.726940e-16  2.550050e-16  2.697850e-16  2.710990e-16  2.721460e-16
# 2     4.648300e-16  4.628720e-16  4.802340e-16  4.829550e-16  4.701270e-16
# 3     6.862150e-16  6.875270e-16  6.606990e-16  6.352030e-16  6.405250e-16
# 4     3.434480e-16  3.075180e-16  3.242230e-16  3.265820e-16  3.219980e-16
# ...            ...           ...           ...           ...           ...
# 2994  6.965610e-17  6.328590e-17  5.990640e-17  6.002700e-17  5.926850e-17
# 2995  4.418980e-16  4.588160e-16  4.483320e-16  4.342710e-16  4.412170e-16
# 2996  3.706370e-16  3.703100e-16  3.579550e-16  3.131870e-16  3.156900e-16
# 2997  9.354960e-16  9.804700e-16  9.824680e-16  9.784840e-16  9.073740e-16
# 2998  2.519700e-16  2.674230e-16  2.413720e-16  2.532670e-16  2.347420e-16
#
#       Unnamed: 1001
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 2994            NaN
# 2995            NaN
# 2996            NaN
# 2997            NaN
# 2998            NaN
#
# [2999 rows x 1002 columns]

# %%
# fig, ax = plt.subplots()

# x = df["x"]
# y =  df["y"]

# t = "path"
# # plt.plot(x,y, marker='o', ms=1, linestyle='None')
# plt.plot(x,y)
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# %%
# j = df["x"].to_numpy()

# plt.hist(j, bins = 50)
# plt.xlabel('x position')

# plt.show()

# %%
# j = df["meansquared"].to_numpy()

# plt.hist(j, bins = 50)
# plt.xlabel('meansquared x')

# print(np.median(j) / (4 * 17000))

# plt.show()

# %%
x_list = []
avg_list = []

for cols in df:
    avg_list.append(df[cols].mean())

print("avg: "), avg_list

fig, ax = plt.subplots()

y = avg_list
x = np.linspace(0, 101, 1002)

plt.plot(x,y)
plt.ylabel('mean squared displacement')
plt.tight_layout()
# Out:
# avg:

# %%
# t = "path"
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# model1 = np.poly1d(np.polyfit(df.x, df.y, 1))

# polyline = np.linspace(x[1], x[[len(x)-1]], len(x))
# print(len(x))
# print(x[len(x)-1])

# plt.scatter(df.x, df.y)

# plt.plot(polyline, model1(polyline), color='green')

# def adjR(x, y, degree):
#     results = {}
#     coeffs = np.polyfit(x, y, degree)
#     p = np.poly1d(coeffs)
#     yhat = p(x)
#     ybar = np.sum(y)/len(y)
#     ssreg = np.sum((yhat-ybar)**2)
#     sstot = np.sum((y - ybar)**2)
#     results['r_squared'] = 1- (((1-(ssreg/sstot))*(len(y)-1))/(len(y)-degree-1))

#     return results

# #calculated adjusted R-squared of each model
# print(adjR(df.x, df.y, 1))
