# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
import csv

# %%
# walk2d_df = pd.DataFrame(pd.read_csv("../data_files/randomwalk2d.csv", index_col=0, header=None))
df = pd.DataFrame(pd.read_csv("../data_files/spherediffusion2.csv"))
print(df)
# Out:
#               x          y
# 0       0.00000    0.00000
# 1      -2.83458   -3.75072
# 2       3.17566   -4.86738
# 3      -2.03322   -4.26241
# 4      -3.48132   -7.37032
# ...         ...        ...
# 9996    3.41864  299.02400
# 9997    5.09218  297.85600
# 9998    8.26409  296.01800
# 9999    7.23126  300.67900
# 10000  11.94000  301.34400
#
# [10001 rows x 2 columns]

# %%
fig, ax = plt.subplots()

x = df["x"]
y =  df["y"]

t = "path"
# plt.plot(x,y, marker='o', ms=1, linestyle='None')
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
ax.set_title(t)
ax.set_aspect('equal', adjustable='box')
plt.tight_layout()

# %%
# t = "path"
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# model1 = np.poly1d(np.polyfit(df.x, df.y, 1))

# polyline = np.linspace(x[1], x[[len(x)-1]], len(x))
# print(len(x))
# print(x[len(x)-1])

# plt.scatter(df.x, df.y)

# plt.plot(polyline, model1(polyline), color='green')

# def adjR(x, y, degree):
#     results = {}
#     coeffs = np.polyfit(x, y, degree)
#     p = np.poly1d(coeffs)
#     yhat = p(x)
#     ybar = np.sum(y)/len(y)
#     ssreg = np.sum((yhat-ybar)**2)
#     sstot = np.sum((y - ybar)**2)
#     results['r_squared'] = 1- (((1-(ssreg/sstot))*(len(y)-1))/(len(y)-degree-1))

#     return results

# #calculated adjusted R-squared of each model
# print(adjR(df.x, df.y, 1))
