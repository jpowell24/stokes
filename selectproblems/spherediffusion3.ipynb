# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
import csv

# %%
# walk2d_df = pd.DataFrame(pd.read_csv("../data_files/randomwalk2d.csv", index_col=0, header=None))
df = pd.DataFrame(pd.read_csv("../data_files/spherediffusion3.csv"))
print(df)
# Out:
#                 x   meansquared
# 0    1.204490e-06  7.375770e-13
# 1    6.376720e-07  4.327680e-13
# 2   -1.413440e-07  9.649300e-14
# 3    1.491980e-06  5.980510e-12
# 4   -2.035650e-07  5.176610e-14
# ..            ...           ...
# 995 -9.155890e-07  5.842850e-13
# 996  1.782230e-06  1.344520e-12
# 997  1.018310e-06  3.125030e-13
# 998 -2.003670e-06  6.951180e-12
# 999  3.431270e-06  4.071970e-11
#
# [1000 rows x 2 columns]

# %%
# fig, ax = plt.subplots()

# x = df["x"]
# y =  df["y"]

# t = "path"
# # plt.plot(x,y, marker='o', ms=1, linestyle='None')
# plt.plot(x,y)
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# %%
j = df["x"].to_numpy()

plt.hist(j, bins = 50)
plt.xlabel('x position')

plt.show()

# %%
j = df["meansquared"].to_numpy()

plt.hist(j, bins = 50)
plt.xlabel('meansquared x')

print(np.median(j) / (4 * 1000))

plt.show()
# Out:
# 4.5141875e-16

# %%
# x_list = []
# avg_list = []

# for cols in df:
#     avg_list.append(df[cols].mean())

# print("avg: "), avg_list

# fig, ax = plt.subplots()

# y = avg_list
# x = np.linspace(0, 101, 1002)

# plt.plot(x,y)
# plt.ylabel('mean squared displacement')
# plt.tight_layout()

# %%
# t = "path"
# plt.xlabel('x')
# plt.ylabel('y')
# ax.set_title(t)
# plt.tight_layout()

# model1 = np.poly1d(np.polyfit(df.x, df.y, 1))

# polyline = np.linspace(x[1], x[[len(x)-1]], len(x))
# print(len(x))
# print(x[len(x)-1])

# plt.scatter(df.x, df.y)

# plt.plot(polyline, model1(polyline), color='green')

# def adjR(x, y, degree):
#     results = {}
#     coeffs = np.polyfit(x, y, degree)
#     p = np.poly1d(coeffs)
#     yhat = p(x)
#     ybar = np.sum(y)/len(y)
#     ssreg = np.sum((yhat-ybar)**2)
#     sstot = np.sum((y - ybar)**2)
#     results['r_squared'] = 1- (((1-(ssreg/sstot))*(len(y)-1))/(len(y)-degree-1))

#     return results

# #calculated adjusted R-squared of each model
# print(adjR(df.x, df.y, 1))
